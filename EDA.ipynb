# %%
# Scatter Plot (Earning vs. Earning Potential)
plt.figure(figsize=(6, 4))
plt.scatter(data['Earning'], data['Earning Potential'], alpha=0.5)
plt.title('Scatter Plot: Earning vs. Earning Potential')
plt.xlabel('Earning')
plt.ylabel('Earning Potential')
plt.grid(True)
plt.show()

# %% [markdown]
# **Insight:** Earning potential increases with respect to Earning

# %%
# Line Chart (Age vs. Spending Limit)
plt.figure(figsize=(6, 4))
data.groupby('Age')['Spending Limit'].mean().plot()
plt.title('Line Chart: Age vs. Average Spending Limit')
plt.xlabel('Age')
plt.ylabel('Average Spending Limit')
plt.grid(True)
plt.show()

# %% [markdown]
# **Insight:** Those who are around age 40 spend mid-range whereas others spend the least and most.

# %%
# Pie Chart (Gender Distribution)
gender_counts = data['Gender'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Gender Distribution')
plt.show()

# %% [markdown]
# **Insight:** Males invest more money compare to females.

# %%
# Histogram (Age Distribution)
plt.figure(figsize=(6, 4))
plt.hist(data['Age'], bins=20, edgecolor='k')
plt.title('Histogram: Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# **Insight:** People around 45 to 55 invest more than others

# %%
# Bar Chart (Purchased Product Type)
product_type_counts = data['Purchased Product Type'].value_counts()
plt.figure(figsize=(6, 3))
product_type_counts.plot(kind='bar')
plt.title('Bar Chart: Purchased Product Type')
plt.xlabel('Product Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Insight:** People spend most in electronics than appliances, furnitutes, clothing, books and other

# %%
# Create a boxplot for "Spending Limit" grouped by "Marital Status"
plt.figure(figsize=(6, 4))
data.boxplot(column='Spending Limit', by='Marital Status', vert=False)
plt.title('Boxplot of Spending Limit by Marital Status')
plt.xlabel('Spending Limit')
plt.suptitle('')  # Remove the default title
plt.grid(True)
plt.show()

# %% [markdown]
# **Insight:** Widowed spend less than single, divorced and married
